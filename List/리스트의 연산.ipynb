# %% [markdown]
# # 리스트의 연산

# %% [markdown]
# ## 덧셈 연산

# %%
color1 = ['red', 'blue', 'green']
color2 = ['orange', 'black', 'white']
print(color1 + color2)
# Out:
# ['red', 'blue', 'green', 'orange', 'black', 'white']

# %%
len(color1)
# Out:
# 3

# %%
total_color = color1 + color2

# %%
total_color
# Out:
# ['red', 'blue', 'green', 'orange', 'black', 'white']

# %% [markdown]
# ## 곱셈 연산

# %%
color1 * 2
# Out:
# ['red', 'blue', 'green', 'red', 'blue', 'green']

# %% [markdown]
# ## in 연산

# %%
'blue' in color2 # color 변수에서 문자열 'blue'의 존재 여부 반환
# Out:
# False
